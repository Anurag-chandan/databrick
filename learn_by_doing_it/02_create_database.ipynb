# %%
# %sql
-- Creating database
CREATE DATABASE IF NOT EXISTS pyspark_learning.learn_by_doing_db

# %%
# %sql
-- Creating volume
CREATE VOLUME IF NOT EXISTS pyspark_learning.learn_by_doing_db.volume_files;
-- Creating table 
CREATE TABLE IF NOT EXISTS pyspark_learning.learn_by_doing_db.table_files;
